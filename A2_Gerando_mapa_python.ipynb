# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoandd/Gerando_Mapas_Python/blob/main/A2_Gerando_mapa_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# INSTALANDO A BIBLIOTEA geobr
# !pip install geobr -q

# %%
# INSTALANDO VERSÃO ESPECIFICA DA GEOPANDAS PARA MANIPULAR VETORES
# !pip install rtree -q
# !pip install geopandas==0.12.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# geobr 0.2.0 requires geopandas<0.8.0,>=0.7.0, but you have geopandas 0.12.0 which is incompatible.

# %%
import geobr

# %%
# LISTAR TODOS OS DADOS DISPONÍVEIS NA BIBLIOTEA GEOBR
geobr.list_geobr()

# %%
#OBTENDO OS SETORES CENSITÁRIOS DO CENSO DE 2010 PARA O ESTADO DE SÃO PAULO
censo_sp_2010=geobr.read_census_tract(code_tract="SP", year=2010)

# %%
# PEGANDO OS 5 PRIMEIROS REGISTROS
censo_sp_2010.head(5)

# %%
#VERIFICANDO O NUMERO DE LINHAS E COLUNHAS DO GEODATAFRAME
censo_sp_2010.shape
# Out:
# (68296, 12)

# %%
# VISUALIZAÇÃO DA GEOMETRIA COM A FUNÇÃO PLOT PARA INSPECIONAR OS DADOS
censo_sp_2010.plot()
# Out:
# <Axes: >

# %%
import pandas as pd

# Essa biblioteca fornece ferramentas para análise e manipulação de dados.
# DADOS tabulares como planilha de EXCEL ou uma tabela SQL
# DADOS ordenados de modo temporal ou não
# MATRIZES

# %%
# PEGANDO O NOME DE TODOS OS MUNICIPIOS DO NOSSO GEODATAFRAME
municipio = pd.unique(censo_sp_2010.name_muni)

# %%
# MOSTRA O NÚMERO DE MUNICIPIOS
print(len(municipio))
# Out:
# 645

# %%
print(municipio)

# %%
# BIBLIOTECA USADO PARA CAUSAR UMA PAUSA NA EXECUÇÃO DO CODIGO COM TIME.SLEE
import time

# %%
for mun in municipio:
  print(mun)
  time.sleep(10)

# %%
#ARMAZENANDO NOME DE MUNICIPIOS QUE COMEÇAM COM 'ARA
nomes =[]

for mun in municipio:
  if mun.startswith('Mogi'):
    nomes.append(mun)

nomes

# %%
#OUTRO TIPO DE FOR (ESTUDAR)
nomes=[mun for mun in municipio if mun.startswith('Ara')]
nomes
# Out:
# ['Araçatuba',
#  'Araçariguama',
#  'Araçoiaba Da Serra',
#  'Aramina',
#  'Arandu',
#  'Arapeí',
#  'Araraquara',
#  'Araras']

# %%
#SELECIONANDO APENAS OS SETORES CENSITÁRIOS DE ARARAQUARA E ARMAZENANDO EM UMA NOVA VARIÁVEL

censo_mogi_2010= censo_sp_2010[censo_sp_2010['name_muni']=='Mogi Das Cruzes']

censo_mogi_2010

# %%
# VISUALIZANDO A GEOMETRIA DOS DADOS SELECIONANDOS

censo_mogi_2010.plot()
censo_mogi_2010.head()

# %%
#LENDO AS INSTALAÇÕES DE SAÚDE NO BRASIL E ARMAZENANDO NA VARIÁVEL
saude=geobr.read_health_facilities()

# %%
#VISUALIZANDO GEOMETRIA DOS DADOS
saude.plot()
# Out:
# <Axes: >

# %%
saude.head(1000)

# %%
#SELECIONANDO APENAS OS DADOS DE SAO PAULO

health_sp = saude[saude.abbrev_state=='SP']
health_sp.plot()
# Out:
# <Axes: >

# %%
health_sp.head()
# Out:
#      code_cnes  code_muni  code_state abbrev_state date_update  year_update  \
# 685  2051850.0   355040.0        35.0           SP  2015-05-27       2015.0
# 690  3674509.0   355040.0        35.0           SP  2015-05-27       2015.0
# 706  7063326.0   355040.0        35.0           SP  2015-05-27       2015.0
# 708  2035278.0   355100.0        35.0           SP  2015-05-27       2015.0
# 711  2027550.0   355150.0        35.0           SP  2015-05-27       2015.0
#
#     data_source                     geometry
# 685      SISMOB  POINT (-47.89934 -22.55291)
# 690      SISMOB  POINT (-47.90146 -22.55794)
# 706      SISMOB  POINT (-47.89892 -22.55294)
# 708      SISMOB  POINT (-46.40631 -23.95039)
# 711      SISMOB  POINT (-47.59183 -21.21632)

# %%
health_sp.shape #SHAPE=FORMA
# Out:
# (86599, 8)
